# %%
import pandas as pd

# %%
df=pd.read_csv("Automobile_data.csv")
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.sample(3)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 49     67       toyota    hatchback        95.7   158.7         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 49             four          62               31   6338.0
# 60             four         114               23  13415.0
# 1              four         111               21  16500.0

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
df["company"].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mitsubishi       4
# mercedes-benz    4
# audi             4
# volkswagen       4
# honda            3
# isuzu            3
# chevrolet        3
# jaguar           3
# alfa-romero      3
# porsche          3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
# to get the datatypes of all the rows
# get the statistical view of the data
# get the unique values column wise
# get the most expensive car
#  all Toyota cars
# count total cars per company
# find each companys highest price
# sort all cars by price column
# find average mileage by all car making company

# %%
df["length"].value_counts()
# Out:
# 171.7    4
# 157.3    4
# 158.7    3
# 155.9    3
# 165.3    3
# 169.7    3
# 159.1    3
# 176.8    3
# 176.6    2
# 188.8    2
# 199.6    2
# 172.4    2
# 168.8    2
# 168.9    2
# 190.9    2
# 199.2    1
# 193.8    1
# 189.0    1
# 191.7    1
# 170.2    1
# 175.4    1
# 158.8    1
# 175.7    1
# 171.2    1
# 169.0    1
# 175.0    1
# 184.6    1
# 177.3    1
# 197.0    1
# 169.1    1
# 141.1    1
# 208.1    1
# 192.7    1
# 170.7    1
# 187.8    1
# 157.1    1
# Name: length, dtype: int64

# %%
df["num-of-cylinders"].value_counts()
# Out:
# four      39
# six       11
# five       5
# eight      3
# two        1
# twelve     1
# three      1
# Name: num-of-cylinders, dtype: int64

# %%
df["body-style"].value_counts()
# Out:
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: body-style, dtype: int64

# %%
pd=df[['company','price','body-style']][df.price==df['price'].max()]
pd
# Out:
#           company    price body-style
# 35  mercedes-benz  45400.0    hardtop

# %%
df1=df.groupby('company')
df2=df1.get_group('volvo')
df2
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 59     87   volvo      sedan       104.3   188.8         ohc             four
# 60     88   volvo      wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 59         114               23  12940.0
# 60         114               23  13415.0

# %%
df1=df.groupby('company')
df2=df1.get_group('mercedes-benz')
df2
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 32     44  mercedes-benz      sedan       110.0   190.9         ohc
# 33     45  mercedes-benz      wagon       110.0   190.9         ohc
# 34     46  mercedes-benz      sedan       120.9   208.1        ohcv
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 32             five         123               22  25552.0
# 33             five         123               22  28248.0
# 34            eight         184               14  40960.0
# 35            eight         184               14  45400.0

# %%
df1=df.groupby('company')
df1['company','price'].max()
# Out:
# <ipython-input-22-02d6ae55550b>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1['company','price'].max()
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
df1=df.groupby('company')
df1['company','average-mileage'].mean()
# Out:
# <ipython-input-23-2ec25a7dfbd9>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1['company','average-mileage'].mean()
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
df1=df.groupby('company')
df1['company','price'].max()
df.sort_values(by='company')
# Out:
# <ipython-input-29-cafc9aec9581>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1['company','price'].max()
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 55     80   volkswagen        sedan        97.3   171.7         ohc
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# ...
